# %%
r1 = 35        # Grail
r2 = 36.5      # Exceed


ueb1 = 40/51
ueb2 = 34/51

u1 = 10*100/r1
u2 = 10*100/r2
print(u1, u2)
# Out:
# 28.571428571428573 27.397260273972602

# %%
u1/ueb1, u2/ueb2
# Out:
# (36.42857142857143, 41.09589041095891)
