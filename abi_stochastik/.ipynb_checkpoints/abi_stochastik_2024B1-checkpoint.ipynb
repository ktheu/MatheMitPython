# %% [markdown]
# ### Abi-Stochastik 2024 - Teil B - Aufgabe 1
#
# [Aufgabenstellung](https://www.mathe-aufgaben.com/pruefungsaufgaben/abitur/allg-gymnasien/allg-gymnasien-abiturpruefung-leistungsfach/) -Jahrgang 2024, Teil B, Aufgabensatz 1: Streamingdienst

# %%
def ausgabe(x):
    print(f'{x:.3f}')

# %%
#a

# %% [markdown]
# <img src='b2024_01.png' width='600'>

# %%
#b

# %% [markdown]
# <img src='b2024_03.png' width='250'>

# %%
ausgabe(0.7*0.8/(0.7*0.8+0.3*0.5))
# Out:
# 0.789

# %%
X = binom(40,0.3)
1-X.cdf(5)
# Out:
# np.float64(0.9913819466886258)

# %%
#c
from scipy.stats import binom
n = 6
X = binom(n,0.3)
while 1-X.cdf(5) < 0.99:
    n+=1
    X = binom(n,0.3)
n
# Out:
# 40

# %%
#d

# %%
#e
X = binom(200,0.6)
ausgabe(1-X.cdf(130))
# Out:
# 0.064

# %% [markdown]
# Es muss noch festgestellt werden, dass 131 die kleinste Zahl k ist, für die gilt: 1-X.cdf(k) <= 0.05

# %%
#f
# Ergebnis liegt im Annahmebereich von H0,
# Die Wirklichkeit stimmt aber nicht mit H0 überein
X = binom(200,0.605)
ausgabe(X.cdf(131))
# Out:
# 0.937

# %%
#g
26**8/80**8
# Out:
# 0.0001244706300354004

# %%
(13/40)**8
# Out:
# 0.00012447063003540043

# %%
#h
import math
math.comb(8,2)*74*73
# Out:
# 151256
